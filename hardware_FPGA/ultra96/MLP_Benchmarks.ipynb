          4.3523e-02,  3.7667e+00,  6.5000e-02,  4.2676e+00,  3.8833e-01,
          4.5667e-01,  5.1917e-01,  1.0330e+00,  5.9701e+01,  7.4167e-01,
          8.7347e+01,  1.1453e-01,  1.4103e-01,  1.6996e-01,  2.1905e-01,
          2.2374e+01,  2.1432e-01,  1.5122e+01,  8.6757e-02,  1.1122e-01,
          1.7689e-01,  2.5515e-01,  1.8431e+01,  1.6940e-01,  2.2039e+01,
          1.6815e-02,  7.3402e-02,  6.0702e-02,  5.8686e-02,  7.1914e+00,
          8.7047e-02,  5.5851e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
          0.0000e+00,  2.0000e+00,  0.0000e+00,  0.0000e+00,  2.5355e+00,
          1.7519e+00,  1.0920e+00,  2.6282e+00,  1.1930e+00,  2.3872e+00,
          2.8877e+00],
        [-4.7000e-01, -1.3700e+00, -1.0400e+00,  0.0000e+00, -2.4828e+02,
         -1.4000e+00, -2.9348e+02,  6.3000e-01,  4.2000e-01,  1.3000e-01,
          1.5108e+00,  2.4502e+02,  1.3300e+00,  0.0000e+00, -3.1667e-02,
         -3.8667e-01, -2.7167e-01,  6.2133e-01, -1.6887e+01,  1.1833e-01,
         -1.4402e+02,  2.8136e-01,  5.4044e-01,  3.8800e-01,  6.0004e-01,
          1.4312e+02,  6.4153e-01,  1.2423e+02,  2.1498e-01,  3.4100e-01,
          1.5567e-01,  8.0869e-01,  9.7837e+01,  6.6717e-02,  1.1744e+02,
          9.4333e-01,  2.4409e+02,  3.1667e-02,  9.2451e-02,  3.7333e-02,
          7.8445e-02,  5.8600e+00,  2.8333e-02,  1.7148e+01,  1.3537e-01,
          3.8667e-01,  2.7167e-01,  6.2133e-01,  6.8728e+01,  2.9884e-01,
          1.4402e+02,  7.4422e-02,  1.7656e-01,  1.1822e-01,  2.0428e-01,
          3.6248e+01,  1.6214e-01,  4.1400e+01,  3.3793e-02,  7.5007e-02,
          6.8707e-02,  1.4298e-01,  2.0413e+01,  9.5785e-02,  3.6063e+01,
          3.3947e-02,  5.1575e-02,  7.1832e-02,  9.4888e-02,  2.4095e+01,
          8.7076e-02,  9.5711e+00,  3.0000e+00,  0.0000e+00,  0.0000e+00,
          0.0000e+00,  1.1000e+01,  3.0000e+00,  0.0000e+00,  6.0134e-01,
          1.5716e+00,  5.9122e-01,  1.9156e+00,  1.1022e-01,  3.9510e-01,
          1.8455e+00],
        [ 0.0000e+00, -7.0000e-01, -3.7000e-01,  0.0000e+00, -3.6070e+01,
         -3.6400e+00, -2.9807e+02,  1.2500e+00,  3.0000e-02,  0.0000e+00,
          1.4797e+00,  2.5198e+02,  0.0000e+00,  3.1214e+02,  9.2583e-01,
         -2.3250e-01, -1.5750e-01,  9.8134e-01,  2.7002e+01, -2.7650e+00,
         -5.9119e+01,  3.0245e-01,  1.9197e-01,  9.7222e-02,  3.3283e-01,
          8.1417e+01,  8.7685e-01,  2.7282e+02,  1.5567e-01,  1.1861e-01,
          8.8956e-02,  1.4994e-01,  2.0534e+01,  2.8169e-01,  4.2410e+01,
          1.3208e+00,  3.1902e+02,  6.2500e-02,  2.2048e-02,  3.4359e-03,
          5.8088e-02,  9.2142e+00,  8.6667e-02,  2.2215e+01,  9.2583e-01,
          2.3250e-01,  1.5750e-01,  9.8134e-01,  3.5200e+01,  2.7650e+00,
          1.5922e+02,  1.5874e-01,  6.6095e-02,  3.6583e-02,  1.7092e-01,
          2.3054e+01,  4.6250e-01,  6.7039e+01,  2.3207e-01,  5.6632e-02,
          3.8943e-02,  2.4550e-01,  9.0382e+00,  6.9804e-01,  4.4716e+01,
          2.5140e-02,  2.8543e-02,  1.0680e-02,  1.3088e-02,  9.0460e+00,
          9.1929e-02,  3.1078e+01,  0.0000e+00,  0.0000e+00,  0.0000e+00,
          0.0000e+00,  3.0000e+00,  0.0000e+00,  1.0000e+00,  2.9789e+00,
          2.0494e+00,  2.3693e+00,  2.9647e+00, -2.7296e-01,  2.9554e+00,
          1.1993e+00],
        [-8.8000e-01, -5.9000e-01, -1.3600e+00,  0.0000e+00, -1.4770e+01,
         -3.2400e+00, -2.1201e+02,  1.4500e+00,  5.7000e-01,  7.1000e-01,
          1.7172e+00,  7.4440e+01,  1.3500e+00,  0.0000e+00,  3.6667e-01,
         -6.6667e-02,  8.6667e-02,  7.7633e-01,  7.9092e+00, -9.4833e-01,
         -1.0652e+02,  7.8781e-01,  2.6622e-01,  5.5067e-01,  7.3380e-01,
          2.5317e+01,  1.6098e+00,  9.2806e+01,  6.5234e-01,  2.0756e-01,
          6.0787e-01,  9.8142e-01,  2.5056e+00,  1.7643e+00,  1.0052e+02,
          1.1817e+00,  1.2086e+02,  1.6667e-03,  2.8189e-02,  4.1667e-02,
          1.1264e-01,  1.6242e+00,  5.4913e-02,  4.8316e+00,  3.6667e-01,
          1.2493e-01,  2.3295e-01,  7.7633e-01,  1.0055e+01,  9.4833e-01,
          1.0652e+02,  2.1359e-01,  7.1002e-02,  1.4704e-01,  2.4312e-01,
          7.1953e+00,  4.6616e-01,  3.1547e+01,  1.3154e-01,  3.5145e-02,
          6.5373e-02,  1.8971e-01,  2.6178e+00,  2.7131e-01,  2.5849e+01,
          7.1133e-02,  5.5701e-02,  1.0542e-01,  5.4550e-02,  2.4860e+00,
          3.2345e-01,  1.7074e+01,  0.0000e+00,  2.0000e+00,  1.0000e+00,
          0.0000e+00,  7.0000e+00,  0.0000e+00,  0.0000e+00, -4.4600e-01,
          1.4433e-01, -7.5662e-02,  1.8256e+00, -7.4275e-01, -8.8135e-02,
          1.8063e+00],
        [-1.9000e-01, -1.1700e+00, -1.4000e+00,  0.0000e+00, -2.4828e+02,
         -1.4600e+00, -2.7308e+02,  9.6000e-01,  1.3000e-01,  7.5000e-01,
          1.8745e+00,  1.4174e+02,  1.1800e+00,  0.0000e+00,  3.1833e-01,
         -3.5583e-01, -3.7417e-01,  9.1160e-01, -3.9824e+01, -5.8917e-01,
         -1.9573e+02,  3.3590e-01,  3.7295e-01,  7.1853e-01,  5.5241e-01,
          1.1858e+02,  7.9962e-01,  8.8884e+01,  3.6324e-01,  3.9289e-01,
          8.5991e-01,  5.8665e-01,  5.6428e+01,  8.0802e-01,  2.0178e+01,
          1.4250e+00,  2.8134e+02,  6.9046e-02,  7.1846e-02,  6.2277e-02,
          1.5674e-02,  1.9644e+01,  1.0083e-01,  3.1967e+00,  3.1833e-01,
          3.5583e-01,  4.1271e-01,  9.1160e-01,  5.2029e+01,  5.8917e-01,
          1.9573e+02,  1.1477e-01,  1.2748e-01,  1.9329e-01,  2.0875e-01,
          3.4235e+01,  2.5979e-01,  3.5013e+01,  6.8372e-02,  7.6747e-02,
          1.3164e-01,  2.2606e-01,  1.1488e+01,  1.2133e-01,  5.1235e+01,
          1.2808e-02,  4.4336e-02,  1.2777e-01,  8.8329e-02,  1.6917e+01,
          7.0560e-02,  2.6688e+01,  0.0000e+00,  0.0000e+00,  1.0000e+00,
          0.0000e+00,  1.0000e+00,  0.0000e+00,  0.0000e+00,  2.1487e+00,
          2.1225e+00,  6.6490e-01,  2.3786e+00,  1.7700e-01,  1.4584e+00,
          2.4677e+00],
        [-8.6000e-01, -4.2000e-01, -1.0500e+00,  3.8092e-01, -9.7710e+01,
         -3.7900e+00, -1.7180e+01,  1.8600e+00,  4.9000e-01,  5.2000e-01,
          1.9403e+00,  7.3090e+01,  3.1000e+00,  6.6480e+01,  8.3750e-01,
         -1.3667e-01,  2.1417e-01,  1.2595e+00, -1.4450e+01, -1.5283e+00,
          2.7042e+01,  9.1298e-01,  2.4730e-01,  4.2347e-01,  5.0365e-01,
          4.5810e+01,  2.3071e+00,  2.6268e+01,  7.1906e-01,  1.4085e-01,
          1.5567e-01,  3.5492e-01,  4.7325e+01,  1.6457e+00,  3.4767e+01,
          1.7817e+00,  7.1478e+01,  2.0632e-02,  7.9495e-03,  1.0833e-02,
          4.5785e-02,  8.6636e+00,  2.6673e-01,  9.4500e-01,  8.3750e-01,
          1.3667e-01,  2.1417e-01,  1.2595e+00,  2.0606e+01,  1.5283e+00,
          2.7042e+01,  2.4812e-01,  6.9867e-02,  1.2428e-01,  2.3058e-01,
          1.3219e+01,  6.5957e-01,  7.5959e+00,  2.5759e-01,  4.2088e-02,
          5.7633e-02,  3.1649e-01,  4.1887e+00,  4.5075e-01,  7.7938e+00,
          1.1621e-01,  6.0977e-02,  7.9871e-02,  8.4225e-02,  3.2921e+00,
          2.0393e-01,  2.4250e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
          0.0000e+00,  1.0000e+00,  0.0000e+00,  0.0000e+00,  1.0528e+00,
         -4.0336e-02, -3.1543e-01,  2.8080e+00,  6.7805e-01,  8.7715e-01,
          1.2883e+00]], dtype=np.single)
labels = np.asarray([1, 0, 8, 3, 2, 5, 8, 6, 4, 4, 8, 0, 0, 6, 6, 2, 6, 4, 3, 7, 1, 1, 2, 4,
        3, 2, 3, 2, 7, 6, 2, 6], dtype=np.int32)

# %% [markdown]
# # Software implementation

# %%
import os, sys
import torch
from torch import nn

sys.path.insert(1, os.path.abspath(os.getcwd() + "/../../sw1_ml/src/model/"))
from neural_network_model import neural_network_model_fpga

save_path = os.path.abspath(os.getcwd() + "/../../sw1_ml/notebooks/NN_9moves_WY_85.pt")
sys.path.insert(2, save_path)
model = neural_network_model_fpga(86, [256, 128], 9)
model.load_state_dict(torch.load(save_path))
# Out:
# <All keys matched successfully>

# %%
#print(labels)
import time
model.to("cpu")
total = len(labels)
correct = 0
print(total)
time_list = []
for i, inp in enumerate(inputs):
    time_start= time.time()
    outputs = model(torch.from_numpy(np.asarray([inp])))
    time_list.append((time.time() - time_start ) * 1000)
    _, predicted = torch.max(outputs, 1)
    if(predicted == labels[i]):
        correct += 1

print("avg_time = ", sum(time_list)/ len(time_list), 'ms')
print("accuracy:" , correct / total * 100 , "%")
# Out:
# 32
# avg_time =  1.0181516408920288 ms
# accuracy: 93.75 %

# %% [markdown]
# # Hardware implementation

# %%
from pynq import Overlay
import pynq.lib.dma
from pynq import DefaultIP
from pynq import allocate
import struct
from struct import pack, unpack
overlay = Overlay('/home/xilinx/CG4002_2/CG4002_B18/hardware_FPGA/ultra96/Vivado/bitstreams/MLP_no_opts/design_1.bit')
dma = overlay.axi_dma_0 
def log_softmax(x):
    e_x = np.exp(x - np.max(x))
    return np.log(e_x / e_x.sum())

def MLP_predict(inputs, overlay, dma):
    #print(f"{len(inputs)}")
    #print(f"inputs: {inputs}")
    output = []
    in_buffer = allocate(shape=(86,), dtype=np.int32)
    for i in range(86):
        in_buffer[i] = unpack('i', pack('f',inputs[i]))[0];
    #print(in_buffer)
    out_buffer = allocate(shape=(9,), dtype=np.int32)
    dma.sendchannel.transfer(in_buffer)
    dma.recvchannel.transfer(out_buffer)
    dma.sendchannel.wait()
    dma.recvchannel.wait()
    #print(out_buffer[0:3])
    for i in range(9):
        output.append(unpack('f', pack('i',out_buffer[i]))[0]);
    #print(output)
    output = log_softmax(output)
    #print(output)
    output = (output.tolist().index(max(output)))
    #print(output)
    return(output)

total = len(labels)
correct = 0
print(total)
time_list = []
for i, inp in enumerate(inputs):
    time_start= time.time()
    output = MLP_predict(inp,overlay ,dma)
    time_list.append((time.time() - time_start )* 1000)
    if(labels[i] == output):
        correct += 1
print("accuracy:" , correct / total * 100 , "%")
print("avg_time = ", sum(time_list)/ len(time_list), 'ms')
# Out:
# 32
# accuracy: 93.75 %
# avg_time =  7.005639374256134 ms

# %% [markdown]
# # Optimized version

# %%
from pynq import Overlay
import pynq.lib.dma
from pynq import DefaultIP
from pynq import allocate
import struct
from struct import pack, unpack
overlay = Overlay('/home/xilinx/CG4002_2/CG4002_B18/hardware_FPGA/ultra96/Vivado/bitstreams/MLP_opt/design_1.bit')
dma = overlay.axi_dma_0 
def log_softmax(x):
    e_x = np.exp(x - np.max(x))
    return np.log(e_x / e_x.sum())

def MLP_predict(inputs, overlay, dma):
    #print(f"{len(inputs)}")
    #print(f"inputs: {inputs}")
    output = []
    in_buffer = allocate(shape=(86,), dtype=np.int32)
    for i in range(86):
        in_buffer[i] = unpack('i', pack('f',inputs[i]))[0];
    #print(in_buffer)
    out_buffer = allocate(shape=(9,), dtype=np.int32)
    dma.sendchannel.transfer(in_buffer)
    dma.recvchannel.transfer(out_buffer)
    dma.sendchannel.wait()
    dma.recvchannel.wait()
    #print(out_buffer[0:3])
    for i in range(9):
        output.append(unpack('f', pack('i',out_buffer[i]))[0]);
    #print(output)
    output = log_softmax(output)
    #print(output)
    output = (output.tolist().index(max(output)))
    #print(output)
    return(output)

total = len(labels)
correct = 0
print(total)
time_list = []
for i, inp in enumerate(inputs):
    time_start= time.time()
    output = MLP_predict(inp,overlay ,dma)
    time_list.append((time.time() - time_start )* 1000)
    if(labels[i] == output):
        correct += 1
print("accuracy:" , correct / total * 100 , "%")
print("avg_time = ", sum(time_list)/ len(time_list), 'ms')
# Out:
# 32
# accuracy: 93.75 %
# avg_time =  6.583496928215027 ms
